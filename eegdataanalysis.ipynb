# %% [markdown]
# # EEG data analysis

# %% [markdown]
# # 1. EEG visualization

# %% [markdown]
# # 1.1. EEG visualization for groups (SHAM, LCN, AUD) with averaged trials of all mice

# %%
import scipy.io  # Import SciPy's io module for reading .mat files
import numpy as np  # Import NumPy for numerical operations
import matplotlib.pyplot as plt  # Import Matplotlib for plotting

# Load the .mat file data
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")

# Get the mean values across trials for three different conditions
t1 = mat['SHAM']['trials'][0][0][:, 0, :].mean(axis=0)  # Mean of the first trial
t2 = mat['SHAM']['trials'][0][0][:, 1, :].mean(axis=0)  # Mean of the second trial
t3 = mat['SHAM']['trials'][0][0][:, 2, :].mean(axis=0)  # Mean of the third trial

# Get the time values from the .mat file
time = mat['SHAM']["Time"][0][0]

# Flatten the time array to a one-dimensional array
x = np.ndarray.flatten(time)

# Transpose the flattened time array
x = np.transpose(x)

# Create a new figure with specified size for plotting
plt.figure(figsize=(15, 4.8))

# Plot the mean trial values against time for each condition
plt.plot(x, t1, '-')  # Plot for the first trial
plt.plot(x, t2, '-')  # Plot for the second trial
plt.plot(x, t3, '-')  # Plot for the third trial

# Set the title for the plot
plt.title("Grand mean for SHAM vs. time")

# Label the x-axis
plt.xlabel("time")

# Label the y-axis
plt.ylabel("trial value")

# Display the plot
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][:,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][:,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][:,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("Grand mean for LCN vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][:,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][:,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][:,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("Grand mean for AUD vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %% [markdown]
# # 1.2. EEG visualization for "LCN" group mice

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][0:184,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][0:184,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][0:184,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 2 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][185:397,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][185:397,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][185:397,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 3 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][398:609,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][398:609,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][398:609,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 4 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][610:796,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][610:796,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][610:796,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 5 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][797:1012,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][797:1012,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][797:1012,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 6 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['LCN']['trials'][0][0][1013:1227,0,:].mean(axis = 0)
t2=mat['LCN']['trials'][0][0][1013:1227,1,:].mean(axis = 0)
t3=mat['LCN']['trials'][0][0][1013:1227,2,:].mean(axis = 0)
time=mat['LCN']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("LCN, Mean for Rat_ID 7 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %% [markdown]
# # 1.3. EEG visualization for "SHAM" group mice

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][0:201,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][0:201,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][0:201,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 1 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][202:391,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][202:391,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][202:391,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 2 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][392:593,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][392:593,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][392:593,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 3 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][594:789,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][594:789,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][594:789,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 4 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][790:985,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][790:985,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][790:985,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 5 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['SHAM']['trials'][0][0][986:1118,0,:].mean(axis = 0)
t2=mat['SHAM']['trials'][0][0][986:1118,1,:].mean(axis = 0)
t3=mat['SHAM']['trials'][0][0][986:1118,2,:].mean(axis = 0)
time=mat['SHAM']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("SHAM, Mean for Rat_ID 6 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %% [markdown]
# # 1.4. EEG visualization for "AUD" group mice

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][0:184,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][0:184,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][0:184,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 2 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][185:393,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][185:393,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][185:393,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 3 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][394:589,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][394:589,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][394:589,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 5 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][590:780,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][590:780,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][590:780,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 6 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][781:989,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][781:989,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][781:989,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 7 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
mat = scipy.io.loadmat(r"C:\Users\ablay\Downloads\LIFU_Anvar.mat")
t1=mat['AUD']['trials'][0][0][990:1135,0,:].mean(axis = 0)
t2=mat['AUD']['trials'][0][0][990:1135,1,:].mean(axis = 0)
t3=mat['AUD']['trials'][0][0][990:1135,2,:].mean(axis = 0)
time=mat['AUD']["Time"][0][0]
x=np.ndarray.flatten(time)
x=np.transpose(x)
plt.figure(figsize=(15,4.8))
plt.plot(x,t1,'-')
plt.plot(x,t2,'-')
plt.plot(x,t3,'-')
plt.title("AUD, Mean for Rat_ID 9 vs. time")
plt.xlabel("time")
plt.ylabel("trial value")
plt.show()

# %% [markdown]
# # 2. Time-frequency analysis

# %% [markdown]
# # 2.1. Time-frequency analysis for "AUD"

# %%
import numpy as np  # Import NumPy for numerical operations
import scipy.io as sio  # Import SciPy's io module for reading .mat files
import mne  # Import MNE for processing EEG data
import matplotlib.pyplot as plt  # Import Matplotlib for plotting
from mne.time_frequency import tfr_multitaper  # Import the multitaper time-frequency representation function

# Define the file path for the .mat file containing the EEG data
file_path = r"C:\Users\ablay\Downloads\LIFU_Anvar.mat"

# Load the .mat file data into a dictionary
mat_data = sio.loadmat(file_path)

# Extract EEG trials and compute the mean across trials
eeg_data = mat_data['AUD']['trials'][0][0].mean(axis=0)

# Define the sampling rate (in Hz)
sampling_rate = 1000

# Determine the number of channels and time points from the EEG data shape
n_channels = eeg_data.shape[0]
n_times = eeg_data.shape[1]

# Create an MNE Info object with channel names, sampling frequency, and channel types
info = mne.create_info(ch_names=['Mc', 'Mi', 'Aud'], sfreq=sampling_rate, ch_types='eeg')

# Create a RawArray object from the EEG data and info
raw = mne.io.RawArray(eeg_data, info)

# Define the frequency range for time-frequency analysis
frequencies = np.arange(6, 30, 1)  # Frequencies from 6 to 30 Hz
n_cycles = frequencies / 2.0  # Number of cycles for each frequency (half of the frequency)

# Perform multitaper time-frequency representation on the raw EEG data
power = tfr_multitaper(raw, freqs=frequencies, n_cycles=n_cycles, time_bandwidth=2.0, return_itc=False)

# Define the starting time for the plot adjustments
negative_start = -0.5

# Adjust the time values of the power data for plotting
adjusted_times = power.times + negative_start

# List of channel names for labeling the plots
chnnls = ["Mc", "Mi", "Aud"]

# Loop through each channel's power data to create individual plots
for i in range(power.data.shape[0]):
    plt.figure()  # Create a new figure for each channel
    plt.imshow(power.data[i], aspect='auto', origin='lower',
               extent=[adjusted_times[0], adjusted_times[-1], frequencies[0], frequencies[-1]],
               cmap='jet', interpolation='bilinear',vmin=0, vmax=10000)  # Plot the power data as an image
    plt.colorbar(label='Power (dB)')  # Add a color bar indicating power in decibels
    plt.title(f'AUD Power Spectrogram - ' + chnnls[i])  # Set the title for the plot
    plt.xlabel('Time (s)')  # Label the x-axis
    plt.ylabel('Frequency (Hz)')  # Label the y-axis
    plt.xlim([-0.5, 2.5])  # Set x-axis limits
    plt.ylim([5, 30])  # Set y-axis limits
    plt.show()  # Display the current figure

# %% [markdown]
# # 2.2. Time-frequency analysis for "LCN"

# %%
import numpy as np  # Import NumPy for numerical operations
import scipy.io as sio  # Import SciPy's io module for reading .mat files
import mne  # Import MNE for processing EEG data
import matplotlib.pyplot as plt  # Import Matplotlib for plotting
from mne.time_frequency import tfr_multitaper  # Import the multitaper time-frequency representation function

# Define the file path for the .mat file containing the EEG data
file_path = r"C:\Users\ablay\Downloads\LIFU_Anvar.mat"

# Load the .mat file data into a dictionary
mat_data = sio.loadmat(file_path)

# Extract EEG trials and compute the mean across trials
eeg_data = mat_data['LCN']['trials'][0][0].mean(axis=0)

# Define the sampling rate (in Hz)
sampling_rate = 1000

# Determine the number of channels and time points from the EEG data shape
n_channels = eeg_data.shape[0]
n_times = eeg_data.shape[1]

# Create an MNE Info object with channel names, sampling frequency, and channel types
info = mne.create_info(ch_names=['Mc', 'Mi', 'Aud'], sfreq=sampling_rate, ch_types='eeg')

# Create a RawArray object from the EEG data and info
raw = mne.io.RawArray(eeg_data, info)

# Define the frequency range for time-frequency analysis
frequencies = np.arange(6, 30, 1)  # Frequencies from 6 to 30 Hz
n_cycles = frequencies / 2.0  # Number of cycles for each frequency (half of the frequency)

# Perform multitaper time-frequency representation on the raw EEG data
power = tfr_multitaper(raw, freqs=frequencies, n_cycles=n_cycles, time_bandwidth=2.0, return_itc=False)

# Define the starting time for the plot adjustments
negative_start = -0.5

# Adjust the time values of the power data for plotting
adjusted_times = power.times + negative_start

# List of channel names for labeling the plots
chnnls = ["Mc", "Mi", "Aud"]

# Loop through each channel's power data to create individual plots
for i in range(power.data.shape[0]):
    plt.figure()  # Create a new figure for each channel
    plt.imshow(power.data[i], aspect='auto', origin='lower',
               extent=[adjusted_times[0], adjusted_times[-1], frequencies[0], frequencies[-1]],
               cmap='jet', interpolation='bilinear', vmin=0, vmax=6000)  # Plot the power data as an image
    plt.colorbar(label='Power (dB)')  # Add a color bar indicating power in decibels
    plt.title(f'LCN Power Spectrogram - ' + chnnls[i])  # Set the title for the plot
    plt.xlabel('Time (s)')  # Label the x-axis
    plt.ylabel('Frequency (Hz)')  # Label the y-axis
    plt.xlim([-0.5, 2.5])  # Set x-axis limits
    plt.ylim([5, 30])  # Set y-axis limits
    plt.show()  # Display the current figure

# %% [markdown]
# # 2.3. Induced response (power spectrogram) for "AUD"

# %%
import numpy as np
import scipy.io as sio
import mne
import matplotlib.pyplot as plt
from mne.time_frequency import tfr_multitaper
import logging

# Suppress the printing of legacy function warning
logging.getLogger('mne').setLevel(logging.CRITICAL)

# Load the data
file_path = r"C:\Users\ablay\Downloads\LIFU_Anvar.mat"
mat_data = sio.loadmat(file_path)

# Extract individual trials
eeg_data = mat_data['AUD']['trials'][0][0]  # Assuming this contains trials
eeg_data = np.transpose(eeg_data, (1, 0, 2))
# The sampling rate
sampling_rate = 1000

# Create MNE Raw object with all trials
n_channels = eeg_data.shape[0]
n_trials = eeg_data.shape[1]
info = mne.create_info(ch_names=['Mc', 'Mi', 'Aud'], sfreq=sampling_rate, ch_types='eeg')

# Create a list to store power for each trial
power_trials = []

# Calculate power for each trial
for trial_index in range(n_trials):
    trial_data = eeg_data[:, trial_index, :]  # Select one trial
    raw = mne.io.RawArray(trial_data, info)
    frequencies = np.arange(6, 30, 1)
    n_cycles = frequencies / 2.0
    power = tfr_multitaper(raw, freqs=frequencies, n_cycles=n_cycles, time_bandwidth=2.0, return_itc=False)
    power_trials.append(power.data)  # Store the power for this trial

# Convert the list of trial powers to a 3D numpy array (trials x frequencies x times)
power_trials = np.array(power_trials)

# Average power across the trials (shape: frequencies x times)
avg_power = np.mean(power_trials, axis=0)

# Adjusted times for the plotting
negative_start = -0.5
adjusted_times = power.times + negative_start
chnnls = ["Mc", "Mi", "Aud"]

# Plot average power for each channel
import matplotlib as mplt
mplt.style.use('classic')
for i in range(avg_power.shape[0]):
    plt.figure()
    plt.imshow(avg_power[i], aspect='auto', origin='lower',
               extent=[adjusted_times[0], adjusted_times[-1], frequencies[0], frequencies[-1]],
               cmap='jet', interpolation='bilinear')
    plt.colorbar(label='Power (dB)')
    plt.title(f'AUD Induced Power Spectrogram - ' + chnnls[i])
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')
    plt.xlim([-0.5, 2.5])
    plt.ylim([5, 30])
    plt.show(block=True)

# %% [markdown]
# # 2.3. Induced response (power spectrogram) for "LCN"

# %%
import numpy as np
import scipy.io as sio
import mne
import matplotlib.pyplot as plt
from mne.time_frequency import tfr_multitaper
import logging

# Suppress the printing of legacy function warning
logging.getLogger('mne').setLevel(logging.CRITICAL)

# Load the data
file_path = r"C:\Users\ablay\Downloads\LIFU_Anvar.mat"
mat_data = sio.loadmat(file_path)

# Extract individual trials
eeg_data = mat_data['LCN']['trials'][0][0]  # Assuming this contains trials
eeg_data = np.transpose(eeg_data, (1, 0, 2))

# The sampling rate
sampling_rate = 1000

# Create MNE Raw object with all trials
n_channels = eeg_data.shape[0]
n_trials = eeg_data.shape[1]
info = mne.create_info(ch_names=['Mc', 'Mi', 'Aud'], sfreq=sampling_rate, ch_types='eeg')

# Create a list to store power for each trial
power_trials = []

# Calculate power for each trial
for trial_index in range(n_trials):
    trial_data = eeg_data[:, trial_index, :]  # Select one trial
    raw = mne.io.RawArray(trial_data, info)
    frequencies = np.arange(6, 30, 1)
    n_cycles = frequencies / 2.0
    power = tfr_multitaper(raw, freqs=frequencies, n_cycles=n_cycles, time_bandwidth=2.0, return_itc=False)
    power_trials.append(power.data)  # Store the power for this trial

# Convert the list of trial powers to a 3D numpy array (trials x frequencies x times)
power_trials = np.array(power_trials)

# Average power across the trials (shape: frequencies x times)
avg_power = np.mean(power_trials, axis=0)

# Adjusted times for the plotting
negative_start = -0.5
adjusted_times = power.times + negative_start
chnnls = ["Mc", "Mi", "Aud"]

# Plot average power for each channel
import matplotlib as mplt
mplt.style.use('classic')
for i in range(avg_power.shape[0]):
    plt.figure()
    plt.imshow(avg_power[i], aspect='auto', origin='lower',
               extent=[adjusted_times[0], adjusted_times[-1], frequencies[0], frequencies[-1]],
               cmap='jet', interpolation='bilinear')
    plt.colorbar(label='Power (dB)')
    plt.title(f'LCN Induced Power Spectrogram - ' + chnnls[i])
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')
    plt.xlim([-0.5, 2.5])
    plt.ylim([5, 30])
    plt.show(block=True)
